# %% [markdown]
# # Logistic Regression Consulting Project

# %% [markdown]
# ## Binary Customer Churn
#
# A marketing agency has many customers that use their service to produce ads for the client/customer websites. They've noticed that they have quite a bit of churn in clients. They basically randomly assign account managers right now, but want you to create a machine learning model that will help predict which customers will churn (stop buying their service) so that they can correctly assign the customers most at risk to churn an account manager. Luckily they have some historical data, can you help them out? Create a classification algorithm that will help classify whether or not a customer churned. Then the company can test this against incoming data for future customers to predict which customers will churn and assign them an account manager.
#
# The data is saved as customer_churn.csv. Here are the fields and their definitions:
#
#     Name : Name of the latest contact at Company
#     Age: Customer Age
#     Total_Purchase: Total Ads Purchased
#     Account_Manager: Binary 0=No manager, 1= Account manager assigned
#     Years: Totaly Years as a customer
#     Num_sites: Number of websites that use the service.
#     Onboard_date: Date that the name of the latest contact was onboarded
#     Location: Client HQ Address
#     Company: Name of Client Company
#
# Once you've created the model and evaluated it, test out the model on some new data (you can think of this almost like a hold-out set) that your client has provided, saved under new_customers.csv. The client wants to know which customers are most likely to churn given this data (they don't have the label yet).

# %% [markdown]
# #### Análisis exploratorio de variables

# %%
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder.appName('Churn').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.read.csv('/FileStore/tables/customer_churn.csv',header=True,inferSchema=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.limit(20).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Names</th>
#       <th>Age</th>
#       <th>Total_Purchase</th>
#       <th>Account_Manager</th>
#       <th>Years</th>
#       <th>Num_Sites</th>
#       <th>Onboard_date</th>
#       <th>Location</th>
#       <th>Company</th>
#       <th>Churn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Brenda Hall</td>
#       <td>37.0</td>
#       <td>11628.10</td>
#       <td>1</td>
#       <td>6.83</td>
#       <td>10.0</td>
#       <td>2010-02-20 16:08:12</td>
#       <td>1877 Tara Streets West Sarah, MN 39500</td>
#       <td>Rosales Inc</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Richard Farmer</td>
#       <td>44.0</td>
#       <td>8588.46</td>
#       <td>1</td>
#       <td>7.77</td>
#       <td>8.0</td>
#       <td>2012-05-07 09:58:33</td>
#       <td>115 Courtney Springs Suite 396 Jenniferland, I...</td>
#       <td>Schroeder, Hines and Thompson</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Teresa Garcia</td>
#       <td>46.0</td>
#       <td>11343.33</td>
#       <td>1</td>
#       <td>3.69</td>
#       <td>8.0</td>
#       <td>2012-09-20 05:52:41</td>
#       <td>2374 Jackson Walks Larryberg, PW 89438-7588</td>
#       <td>Ibarra and Sons</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Kevin Hicks DDS</td>
#       <td>49.0</td>
#       <td>9957.26</td>
#       <td>0</td>
#       <td>4.76</td>
#       <td>7.0</td>
#       <td>2009-09-01 11:37:22</td>
#       <td>096 Dunn Street Jasonshire, NC 06461-2275</td>
#       <td>Cooper, Mcguire and Nguyen</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Benjamin Huff</td>
#       <td>45.0</td>
#       <td>8871.53</td>
#       <td>0</td>
#       <td>3.76</td>
#       <td>8.0</td>
#       <td>2007-03-06 12:55:46</td>
#       <td>205 Hall Mission Apt. 211 South Matthew, HI 81...</td>
#       <td>Hurley, Moody and Gomez</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>
td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Samantha Flores</td>
#       <td>39.0</td>
#       <td>11670.73</td>
#       <td>0</td>
#       <td>6.45</td>
#       <td>8.0</td>
#       <td>2006-06-24 00:46:18</td>
#       <td>793 Powell Fort Amandaview, GA 95747-4560</td>
#       <td>Williams PLC</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Amanda Barnett</td>
#       <td>45.0</td>
#       <td>9773.22</td>
#       <td>1</td>
#       <td>3.79</td>
#       <td>10.0</td>
#       <td>2009-06-04 09:14:47</td>
#       <td>205 Campbell Highway Port Wyatt, AK 84887-4000</td>
#       <td>Lee Ltd</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Justin Leonard</td>
#       <td>51.0</td>
#       <td>6517.93</td>
#       <td>1</td>
#       <td>5.47</td>
#       <td>10.0</td>
#       <td>2012-05-30 00:15:43</td>
#       <td>49800 Torres Ways Suite 886 West Bradleybury, ...</td>
#       <td>Robles-Abbott</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Harold Griffin</td>
#       <td>41.0</td>
#       <td>6569.87</td>
#       <td>1</td>
#       <td>4.30</td>
#       <td>11.0</td>
#       <td>2015-03-28 02:13:44</td>
#       <td>1774 Peter Row Apt. 712 New Autumn, MT 18782</td>
#       <td>Snyder, Lee and Morris</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
print(df.count(), len(df.columns))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">900 10
# </div>

# %%
df.describe().toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>summary</th>
#       <th>Names</th>
#       <th>Age</th>
#       <th>Total_Purchase</th>
#       <th>Account_Manager</th>
#       <th>Years</th>
#       <th>Num_Sites</th>
#       <th>Location</th>
#       <th>Company</th>
#       <th>Churn</th>
#       <th>Onboard_diff_years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>count</td>
#       <td>900</td>
#       <td>900</td>
#       <td>900</td>
#       <td>900</td>
#       <td>900</td>
#       <td>900</td>
#       <td>900</td>
#       <td>900</td>
#       <td>900</td>
#       <td>900</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>mean</td>
#       <td>None</td>
#       <td>41.81666666666667</td>
#       <td>10062.824033333334</td>
#       <td>0.4811111111111111</td>
#       <td>5.2731555555555545</td>
#       <td>8.587777777777777</td>
#       <td>None</td>
#       <td>None</td>
#       <td>0.16666666666666666</td>
#       <td>9.245256673511296</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>stddev</td>
#       <td>None</td>
#       <td>6.127560416916251</td>
#       <td>2408.644531858093</td>
#       <td>0.49992089350733393</td>
#       <td>1.2744490131946142</td>
#       <td>1.7648355920350922</td>
#       <td>None</td>
#       <td>None</td>
#       <td>0.37288521227723537</td>
#       <td>3.208437030499514</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>min</td>
#       <td>Aaron King</td>
#       <td>22.0</td>
#       <td>100.0</td>
#       <td>0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#       <td>00103 Jeffrey Crest Apt. 205 Padillaville, IA ...</td>
#       <td>Abbott-Thompson</td>
#       <td>0</td>
#       <td>3.5290896646132786</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>max</td>
#       <td>Zachary Walsh</td>
#       <td>65.0</td>
#       <td>18026.01</td>
#       <td>1</td>
#       <td>9.15</td>
#       <td>14.0</td>
#       <td>Unit 9800 Box 2878 DPO AA 75157</td>
#       <td>Zuniga, Clark and Shaffer</td>
#       <td>1</td>
#       <td>14.516084873374401</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Vemos que no hay missing values, eliminaremos duplicados
df = df.dropDuplicates()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(df.count(), len(df.columns))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">900 10
# </div>

# %%
#El Account_Manager fue asignado aleatoriamente, por lo tanto esta variable no será considerada dentro del modelo ya que no debiera aportar información relevante.

#La columna 'Onboard_date' es la fecha en que se incluyó el nombre del último contacto, obtendremos la diferencia en años entre esa fecha y el día de hoy
from pyspark.sql.functions import months_between, col, current_timestamp, datediff
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#
td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Douglas Padilla</td>
#       <td>38.0</td>
#       <td>10863.05</td>
#       <td>1</td>
#       <td>5.59</td>
#       <td>11.0</td>
#       <td>2008-04-28 01:11:37</td>
#       <td>063 Andrew Harbor New Kathleenbury, AR 48898</td>
#       <td>Martinez Ltd</td>
#       <td>1</td>
#       <td>2020-07-09 21:30:10.730</td>
#       <td>12.197125</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Katie Khan</td>
#       <td>40.0</td>
#       <td>10762.29</td>
#       <td>0</td>
#       <td>5.02</td>
#       <td>7.0</td>
#       <td>2015-02-08 22:43:00</td>
#       <td>05418 Smith Brooks Richardfurt, DE 40166-1384</td>
#       <td>Gutierrez, Jones and Winters</td>
#       <td>0</td>
#       <td>2020-07-09 21:30:10.730</td>
#       <td>5.415469</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Donald Flores</td>
#       <td>46.0</td>
#       <td>11580.56</td>
#       <td>1</td>
#       <td>3.43</td>
#       <td>9.0</td>
#       <td>2014-05-09 04:48:30</td>
#       <td>30890 Gloria Oval Friedmanshire, OK 78837-9606</td>
#       <td>Harris-Pratt</td>
#       <td>0</td>
#       <td>2020-07-09 21:30:10.730</td>
#       <td>6.168378</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from pyspark.sql.functions import countDistinct

#Contando las distintas compañías a ver si se repiten
df.agg(countDistinct(col("Company")).alias("count")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+
# count|
# +-----+
#   873|
# +-----+
#
# </div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[185]: [&#39;Names&#39;,
#  &#39;Age&#39;,
#  &#39;Total_Purchase&#39;,
#  &#39;Account_Manager&#39;,
#  &#39;Years&#39;,
#  &#39;Num_Sites&#39;,
#  &#39;Onboard_date&#39;,
#  &#39;Location&#39;,
#  &#39;Company&#39;,
#  &#39;Churn&#39;,
#  &#39;today_date&#39;,
#  &#39;Onboard_diff_years&#39;]</div>

# %%
#Guardaremos los nombres de las columna de interés
cols_model = ['Age',
 'Total_Purchase',
 'Years',
 'Num_Sites',
 'Onboard_diff_years']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Visualizaremos la distribución las features de interés
from matplotlib import cm
import matplotlib.pyplot as plt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fig = plt.figure(figsize=(25,15)) ##Tamaño del plot
st = fig.suptitle("Distribución de features", fontsize=25,
		   verticalalignment='center') #Título principal

for col,num in zip(cols_model,range(1,6)):
  ax = fig.add_subplot(2,3,num)
  ax.hist(df.toPandas()[col])
  #plt.style.use('dark_background')
  plt.grid(False)
  plt.xticks(rotation=45,fontsize=15)
  plt.yticks(fontsize=15)
  plt.title(col,fontsize=20)
  plt.tight_layout()
#st.set_y(0.95)
fig.subplots_adjust(top=0.85,hspace=0.2)
plt.show()

# %% [markdown]
# Se observa que la mayoría de las variables concentra su información en torno a un dato central, excepto onboard_diff_years, que se reparte de manera aproximadamente uniforme en varios valores.

# %%
#Correlación de pearson para las variables numéricas
#Veremos si hay variables que están correlacionadas entre sí
from pyspark.mllib.stat import Statistics
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cols_model_df = df.select(cols_model)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
features = cols_model_df.rdd.map(lambda row: row[0:]) #Convierto a rdd para poder aplicar map y después aplicar la correlación

corr_matrix = Statistics.corr(features, method="pearson")

corr_df = pd.DataFrame(corr_matrix)

corr_df.index, corr_df.columns =cols_model, cols_model   #Asigno los nombres de las variables a los índices de la matriz de correlación
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
corr_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Total_Purchase</th>
#       <th>Years</th>
#       <th>Num_Sites</th>
#       <th>Onboard_diff_years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Age</th>
#       <td>1.000000</td>
#       <td>-0.037208</td>
#       <td>0.005625</td>
#       <td>-0.006070</td>
#       <td>-0.002604</td>
#     </tr>
#     <tr>
#       <th>Total_Purchase</th>
#       <td>-0.037208</td>
#       <td>1.000000</td>
#       <td>-0.005623</td>
#       <td>-0.003390</td>
#       <td>0.020519</td>
#     </tr>
#     <tr>
#       <th>Years</th>
#       <td>0.005625</td>
#       <td>-0.005623</td>
#       <td>1.000000</td>
#       <td>0.051642</td>
#       <td>0.044917</td>
#     </tr>
#     <tr>
#       <th>Num_Sites</th>
#       <td>-0.006070</td>
#       <td>-0.003390</td>
#       <td>0.051642</td>
#       <td>1.000000</td>
#       <td>0.031829</td>
#     </tr>
#     <tr>
#       <th>Onboard_diff_years</th>
#       <td>-0.002604</td>
#       <td>0.020519</td>
#       <td>0.044917</td>
#       <td>0.031829</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Vemos que no hay ninguna correlación significativa entre las variables, luego, las mantendremos todas para el modelo

# %% [markdown]
# #### Construcción del modelo

# %%
#Setearemos los datos al formato requerido por la librería de ml de pyspark

from pyspark.ml.feature import VectorAssembler
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Creamos el objeto assembler
assembler = VectorAssembler(inputCols=cols_model, outputCol='features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Transformamos los datos
output = assembler.transform(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_data = output.select('features','Churn')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_data.toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>features</th>
#       <th>Churn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[37.0, 11628.1, 6.83, 10.0, 10.381930184804927]</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[44.0, 8588.46, 7.77, 8.0, 8.172484599589323]</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[46.0, 11343.33, 3.69, 8.0, 7.800136892539356]</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[49.0, 9957.26, 4.76, 7.0, 10.85284052019165]</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[45.0, 8871.53, 3.76, 8.0, 13.344284736481862]</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Dividimos entre train y test set
train_data, test_data = final_data.randomSplit([0.7,0.3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.classification import LogisticRegression
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Creamos objeto LogisticRegression
log_reg = LogisticRegression(labelCol='Churn')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Ajustamos al train_data

log_reg_model = log_reg.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Voy a llamar evaluate sobre el test set para luego obtener las predicciones sobre ese dataset
prediction_and_labels = log_reg_model.evaluate(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
prediction_and_labels.predictions.toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>features</th>
#       <th>Churn</th>
#       <th>rawPrediction</th>
#       <th>probability</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[44.0, 8588.46, 7.77, 8.0, 8.172484599589323]</td>
#       <td>0</td>
#       <td>[2.3796354605735637, -2.3796354605735637]</td>
#       <td>[0.9152611655401074, 0.08473883445989262]</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[40.0, 10762.29, 5.02, 7.0, 5.415468856947296]</td>
#       <td>0</td>
#       <td>[5.2061259040171315, -5.2061259040171315]</td>
#       <td>[0.9945470242031863, 0.00545297579681374]</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[39.0, 11670.73, 6.45, 8.0, 14.042436687200547]</td>
#       <td>0</td>
#       <td>[2.6875298733856, -2.6875298733856]</td>
#       <td>[0.9362867878333889, 0.06371321216661105]</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[41.0, 6569.87, 4.3, 11.0, 5.284052019164956]</td>
#       <td>1</td>
#       <td>[1.271568444239275, -1.271568444239275]</td>
#       <td>[0.7810111214736825, 0.21898887852631752]</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[42.0, 11783.81, 5.27, 7.0, 9.782340862422998]</td>
#       <td>0</td>
#       <td>[4.536644302386993, -4.536644302386993]</td>
#       <td>[0.9894041900908582, 0.010595809909141824]</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Comparación entre Churn y la predicción
prediction_and_labels.predictions.select('Churn','prediction').toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Churn</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Imprimo esto solo para saber qué contiene:
prediction_and_labels.labels
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[257]: [0.0, 1.0]</div>

# %%
#Crearemos un objeto evaluador para sacar métricas
from pyspark.ml.evaluation import BinaryClassificationEvaluator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Creamos un objeto evaluador
my_eval = BinaryClassificationEvaluator(labelCol ='Churn', rawPredictionCol='prediction')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions = prediction_and_labels.predictions
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions.describe().toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>summary</th>
#       <th>Churn</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>count</td>
#       <td>255</td>
#       <td>255</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>mean</td>
#       <td>0.16862745098039217</td>
#       <td>0.09803921568627451</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>stddev</td>
#       <td>0.3751588619297455</td>
#       <td>0.2979524588712332</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>min</td>
#       <td>0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>max</td>
#       <td>1</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Evalúo sobre el dataframe de predicciones: prediction_and_labels.predictions = predictions
auc = my_eval.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
auc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[286]: 0.734752084247477</div>

# %% [markdown]
# Obtuvimos un AUC de 0.73, es decir, el área bajo la curva ROC es 0.73. El resultado del modelo es decente, aunque podría ser mejor.

# %% [markdown]
# #### Probando el modelo en nuevos datos

# %% [markdown]
# Ahora vamos a probar el modelo en los datos "new_customers.csv"

# %%
#Primero entrenaremos el modelo sobre todos los datos (sin división en train y test)
final_lr_model = log_reg.fit(final_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_data = spark.read.csv('/FileStore/tables/new_customers.csv', header=True, inferSchema=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_data.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Names: string (nullable = true)
# -- Age: double (nullable = true)
# -- Total_Purchase: double (nullable = true)
# -- Account_Manager: integer (nullable = true)
# -- Years: double (nullable = true)
# -- Num_Sites: double (nullable = true)
# -- Onboard_date: timestamp (nullable = true)
# -- Location: string (nullable = true)
# -- Company: string (nullable = true)
#
# </div>

# %%
new_data.toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Names</th>
#       <th>Age</th>
#       <th>Total_Purchase</th>
#       <th>Account_Manager</th>
#       <th>Years</th>
#       <th>Num_Sites</th>
#       <th>Onboard_date</th>
#       <th>Location</th>
#       <th>Company</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Andrew Mccall</td>
#       <td>37.0</td>
#       <td>9935.53</td>
#       <td>1</td>
#       <td>7.71</td>
#       <td>8.0</td>
#       <td>2011-08-29 18:37:54</td>
#       <td>38612 Johnny Stravenue Nataliebury, WI 15717-8316</td>
#       <td>King Ltd</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Michele Wright</td>
#       <td>23.0</td>
#       <td>7526.94</td>
#       <td>1</td>
#       <td>9.28</td>
#       <td>15.0</td>
#       <td>2013-07-22 18:19:54</td>
#       <td>21083 Nicole Junction Suite 332, Youngport, ME...</td>
#       <td>Cannon-Benson</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Jeremy Chang</td>
#       <td>65.0</td>
#       <td>100.00</td>
#       <td>1</td>
#       <td>1.00</td>
#       <td>15.0</td>
#       <td>2006-12-11 07:48:13</td>
#       <td>085 Austin Views Lake Julialand, WY 63726-4298</td>
#       <td>Barron-Robertson</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Megan Ferguson</td>
#       <td>32.0</td>
#       <td>6487.50</td>
#       <td>0</td>
#       <td>9.40</td>
#       <td>14.0</td>
#       <td>2016-10-28 05:32:13</td>
#       <td>922 Wright Branch North Cynthialand, NC 64721</td>
#       <td>Sexton-Golden</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Taylor Young</td>
#       <td>32.0</td>
#       <td>13147.71</td>
#       <td>1</td>
#       <td>10.00</td>
#       <td>8.0</td>
#       <td>2012-03-20 00:36:46</td>
#       <td>Unit 0789 Box 0734 DPO AP 39702</td>
#       <td>Wood LLC</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Añadimos las columnas que creamos cuando entrenamos el modelo
new_data = new_data.withColumn('today_date',current_timestamp())
new_data = new_data.withColumn('Onboard_diff_years', datediff(col('today_date'),col('Onboard_date'))/365.25)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_data.limit(5).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Names</th>
#       <th>Age</th>
#       <th>Total_Purchase</th>
#       <th>Account_Manager</th>
#       <th>Years</th>
#       <th>Num_Sites</th>
#       <th>Onboard_date</th>
#       <th>Location</th>
#       <th>Company</th>
#       <th>today_date</th>
#       <th>Onboard_diff_years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Andrew Mccall</td>
#       <td>37.0</td>
#       <td>9935.53</td>
#       <td>1</td>
#       <td>7.71</td>
#       <td>8.0</td>
#       <td>2011-08-29 18:37:54</td>
#       <td>38612 Johnny Stravenue Nataliebury, WI 15717-8316</td>
#       <td>King Ltd</td>
#       <td>2020-07-09 23:08:25.993</td>
#       <td>8.862423</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Michele Wright</td>
#       <td>23.0</td>
#       <td>7526.94</td>
#       <td>1</td>
#       <td>9.28</td>
#       <td>15.0</td>
#       <td>2013-07-22 18:19:54</td>
#       <td>21083 Nicole Junction Suite 332, Youngport, ME...</td>
#       <td>Cannon-Benson</td>
#       <td>2020-07-09 23:08:25.993</td>
#       <td>6.965092</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Jeremy Chang</td>
#       <td>65.0</td>
#       <td>100.00</td>
#       <td>1</td>
#       <td>1.00</td>
#       <td>15.0</td>
#       <td>2006-12-11 07:48:13</td>
#       <td>085 Austin Views Lake Julialand, WY 63726-4298</td>
#       <td>Barron-Robertson</td>
#       <td>2020-07-09 23:08:25.993</td>
#       <td>13.577002</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Megan Ferguson</td>
#       <td>32.0</td>
#       <td>6487.50</td>
#       <td>0</td>
#       <td>9.40</td>
#       <td>14.0</td>
#       <td>2016-10-28 05:32:13</td>
#       <td>922 Wright Branch North Cynthialand, NC 64721</td>
#       <td>Sexton-Golden</td>
#       <td>2020-07-09 23:08:25.993</td>
#       <td>3.696099</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Taylor Young</td>
#       <td>32.0</td>
#       <td>13147.71</td>
#       <td>1</td>
#       <td>10.00</td>
#       <td>8.0</td>
#       <td>2012-03-20 00:36:46</td>
#       <td>Unit 0789 Box 0734 DPO AP 39702</td>
#       <td>Wood LLC</td>
#       <td>2020-07-09 23:08:25.993</td>
#       <td>8.303901</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
output_new = assembler.transform(new_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Aplico el modelo sobre este unlabeled dataset
predictions_new = final_lr_model.transform(output_new)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Prediccione para estos clientes
predictions_new.toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Names</th>
#       <th>Age</th>
#       <th>Total_Purchase</th>
#       <th>Account_Manager</th>
#       <th>Years</th>
#       <th>Num_Sites</th>
#       <th>Onboard_date</th>
#       <th>Location</th>
#       <th>Company</th>
#       <th>today_date</th>
#       <th>Onboard_diff_years</th>
#       <th>features</th>
#       <th>rawPrediction</th>
#       <th>probability</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>